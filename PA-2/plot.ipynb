# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("checkpoints/VGG-full.csv")
data
# Out:
#     Epoch  Train Loss  Validation Loss
# 0       1    0.025612         0.022114
# 1       2    0.020557         0.018694
# 2       3    0.018339         0.017659
# 3       4    0.017666         0.017303
# 4       5    0.017088         0.017050
# ..    ...         ...              ...
# 95     96    0.011871         0.041064
# 96     97    0.011821         0.042663
# 97     98    0.011756         0.044043
# 98     99    0.011915         0.043949
# 99    100    0.011826         0.044603
#
# [100 rows x 3 columns]

# %%
plt.figure(figsize=(5,5))
plt.plot(data["Epoch"], data["Train Loss"], 'r.-' , label="Training Loss")
plt.plot(data["Epoch"], data["Validation Loss"], 'g.-' , label="Validation Loss")
plt.xlim(0, int(data["Epoch"][-1:-2:-1]))
plt.title("Learning Curves", fontsize=16)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss per epoch")
plt.grid()
# Out:
# /var/folders/f0/06mlnysn0lb8_r2p32h98czm0000gn/T/ipykernel_3174/2640212248.py:4: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   plt.xlim(0, int(data["Epoch"][-1:-2:-1]))

# %%
# Out:
# /var/folders/f0/06mlnysn0lb8_r2p32h98czm0000gn/T/ipykernel_3174/3195808611.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   int(data["Epoch"][-1:-2:-1])
# 100
