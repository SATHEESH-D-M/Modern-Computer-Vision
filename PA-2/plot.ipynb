# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("checkpoints/HED_3.csv")
data
# Out:
#     Epoch  Train Loss  Validation Loss  LR
# 0       1    0.024208         0.021358 NaN
# 1       2    0.020940         0.019827 NaN
# 2       3    0.019986         0.019123 NaN
# 3       4    0.019252         0.018647 NaN
# 4       5    0.018862         0.018285 NaN
# ..    ...         ...              ...  ..
# 95     96    0.015123         0.015855 NaN
# 96     97    0.015046         0.015801 NaN
# 97     98    0.015099         0.015879 NaN
# 98     99    0.015053         0.015805 NaN
# 99    100    0.015065         0.015818 NaN
#
# [100 rows x 4 columns]

# %%
plt.figure(figsize=(5,5))
plt.plot(data["Epoch"], data["Train Loss"], 'r.-' , label="Training Loss")
plt.plot(data["Epoch"], data["Validation Loss"], 'g.-' , label="Validation Loss")
plt.xlim(0, int(data["Epoch"][-1:-2:-1]))
plt.title("Learning Curves", fontsize=16)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss per epoch")
plt.grid()
# Out:
# /var/folders/2x/n83t3hnj2754fpn_pyp160m00000gn/T/ipykernel_80223/2640212248.py:4: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   plt.xlim(0, int(data["Epoch"][-1:-2:-1]))

# %%
# Out:
# /var/folders/f0/06mlnysn0lb8_r2p32h98czm0000gn/T/ipykernel_3174/3195808611.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   int(data["Epoch"][-1:-2:-1])
# 100
